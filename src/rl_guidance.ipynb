# %% [markdown]
# Создадим кастомное окружение по образу и подобию тех, что лежат в ```gym/envs```

# %% [markdown]
# # 1. Проверка работоспособности нашего окружения

# %%
import numpy as np
from math import *
import gym
from IPython.display import clear_output
from time import time

# %%
from aircombat2d import Missile, Target, LineOfSight, AirCombat2D

# %%
def target_autopilot(*args):
    t, = args
#     if t < 3:
#         beta = 0
#     elif t < 5:
#         beta = 10
#     elif t < 7:
#         beta = -10
#     else:
#         beta = 0

    beta = -20

    return np.radians(beta)

# %%
opts = {'los': {
            'r0': 10e3, 
            'chi0': np.radians(0)
        }, 
        'missile':{
            'initial_state': {
                'vel0': 400,
                'psi0': np.radians(180)
            },
            'energetics': {
                't_act': 5,
                'omega_act': 45
            },
            'aerodynamics': {
                'Ms': np.array([0.1, 0.3, 0.5, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1., 1.05, 
                                1.1, 1.15, 1.5, 1.9, 2.3, 2.7, 3.1, 3.5, 3.9, 4.3, 4.7]),
                'Cx0_arr': np.array([0.2958, 0.2998, 0.3078, 0.3198, 0.3234, 0.3273, 0.3314, 
                                     0.3358, 0.3404, 0.3453, 0.3504, 0.3558, 0.3614, 0.4426, 
                                     0.3598, 0.2885, 0.2376, 0.2009, 0.1741, 0.1533, 0.1377, 0.1255]),
                'Cya_arr': np.array([0.0571, 0.0577, 0.0591, 0.0615, 0.0623, 0.0633, 0.0643, 
                                     0.0655, 0.0671, 0.0708, 0.0794, 0.0814, 0.0802, 0.0664,
                                     0.0543, 0.0465, 0.042, 0.0387, 0.0358, 0.0331, 0.0312, 0.0291]),
                'Cyb_arr': np.array([0.0571, 0.0577, 0.0591, 0.0615, 0.0623, 0.0633, 0.0643, 
                                     0.0655, 0.0671, 0.0708, 0.0794, 0.0814, 0.0802, 0.0664, 
                                     0.0543, 0.0465, 0.042, 0.0387, 0.0358, 0.0331, 0.0312, 0.0291])
            }
        }, 
        'target': {
            'vel0': 400,
            'psi0': np.radians(0)            
        }}

# %%
env = AirCombat2D(opts,altitude=15e3,target_autopilot=target_autopilot)
print("Action space:",env.action_space)
print("Observation space:", env.observation_space)

# %%
env = gym.wrappers.TimeLimit(AirCombat2D(opts,altitude=15e3,target_autopilot=target_autopilot).unwrapped, max_episode_steps=200)
# проводим инициализацию и запоминаем начальное состояние
s = env.reset()

done = False
it = 1
start = time()

while not done:
    it += 1
    timeit = time()
    
    # выполняем действие, получаем s, r, done
    s, r, done, _ = env.step(-1)
    
    # визуализируем окружение
    env.render()

#     print(f"Время выполнения {it} шага: {round(time() - timeit, 3)} с", end="\r")

clear_output(True)
print(f"Общее время: {round(time() - start, 3)} с;\nКол-во итераций: {it}.")

env.close()
if s[0] < 10:
    print("Успех!")
else:
    raise NotImplementedError("""
    Исправьте функцию выбора действия!""")

# %% [markdown]
# # 2. Создание DQN сети

# %%
import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from collections import deque
from IPython.display import clear_output
import numpy as np
import matplotlib.pyplot as plt

# если видеокарта доступна, то будем ее использовать
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cuda:0

# %% [markdown]
# ## 2.1 Определяем класс Q-Network

# %%
class QNetwork(nn.Module):
    def __init__(self, n_hid_n):
        """
        определение сети
        """
        super().__init__()
        
        self.fc1 = nn.Linear(8, n_hid_n)
        self.fc2 = nn.Linear(n_hid_n, n_hid_n)
        self.fc3 = nn.Linear(n_hid_n, 3)

    def forward(self, x):
        """
        определение графа вычислений
        :param x: вход
        :return: 
        """
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def sample_action(self, obs, epsilon):
        """
        сэмплирование действия
        :param obs: 
        :param epsilon: 
        :return: 
        """
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0, 2)
        else:
            return out.argmax().item()

# %% [markdown]
# ## 2.2 Реализуем методы класса ReplayBuffer

# %%
class ReplayBuffer():

    def __init__(self, max_size):
        """
        создаем структуру для хранения данных
        """
        self.dq = deque(maxlen=max_size)
        
    def put(self, transition):
        """
        помещаем данные в replay buffer
        :param transition: (s, a, r, next_s, done_mask)
        :return:
        """
        self.dq.append(transition)

    def sample(self, n):
        """
        сэмплируем батч заданного размера
        :param n: размер мини-батча
        :return:
        """
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        # сэмплируем случайный батч и заполняем s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst
        for _ in range(n):
            index = random.randint(0, len(self.dq)-1)
            s_lst.append(self.dq[index][0])
            a_lst.append([self.dq[index][1]]) 
            r_lst.append([self.dq[index][2]]) 
            s_prime_lst.append(self.dq[index][3]) 
            done_mask_lst.append([self.dq[index][4]])

        return torch.tensor(np.array(s_lst), dtype=torch.float), torch.tensor(np.array(a_lst), dtype=torch.int64), \
               torch.tensor(np.array(r_lst)), torch.tensor(np.array(s_prime_lst), dtype=torch.float), \
               torch.tensor(np.array(done_mask_lst))

    def __len__(self):
        """
        возвращает размер replay buffer'а
        :return: len(replay_buffer)
        """
        return len(self.dq)

# %% [markdown]
# ## 2.3 Реализуем функцию тренировки нашей сети

# %%
def train(q, q_target, replay_buffer, optimizer, batch_size, gamma, updates_number=10):
    """
    тренируем нашу архитектуру
    :param q: policy сеть
    :param q_target: target сеть
    :param replay_buffer:
    :param optimizer:
    :param batch_size: размер мини-батча
    :param gamma: дисконтирующий множитель
    :param updates_number: количество обновлений, которые необходимо выполнить
    :return:
    """
    for i in range(updates_number):
        # сэмплируем мини-батч из replay buffer'а
        s, a, r, s_prime, done_mask = replay_buffer.sample(batch_size)

        # получаем полезность, для выбранного действия q сети
        q_out = q(s)
        q_a = q_out.gather(1, a)

        # получаем значение max_q target сети и считаем значение target
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask

        # определяем loss функцию, для q!
        loss = F.smooth_l1_loss(q_a, target.detach())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %% [markdown]
# ## 2.4 Реализуем основную функцию, осуществляющую моделирование и обучение

# %%
def run(q, 
        q_target,
        learning_rate, 
        gamma, 
        buffer_max_size, 
        batch_size, 
        target_update_interval,
        replay_buffer_start_size, 
        print_interval=20, 
        n_episodes=2000, 
        n_env_steps=1000, 
        render=False, 
        reward_history_plot=False,
        epsilon0=0.1):

    # копируем веса q в target_q
    q_target.load_state_dict(q.state_dict())

    # создаем replay buffer
    replay_buffer = ReplayBuffer(max_size=buffer_max_size)

    score = 0.0
    
    infos = []

    # инициализируем оптимизатор, полученным lr
    optimizer = optim.Adam(q.parameters(), lr=learning_rate)

    for n_epi in range(n_episodes):   
        
        # создаем окружение
        env = AirCombat2D(opts, altitude=15e3, target_autopilot=target_autopilot)

        # постепенно изменяем eps с 8% до 1%
        epsilon = max(0.01, 0.1 - 0.01 * (n_epi / 200))
         
        s = env.reset()
        
        # выполянем n_env_steps шагов в окружении и сохраняем, полученные данные
        for t in range(n_env_steps):

            # получаем действие, используя сеть q
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)

            # выполняем действие в окружении
            s_prime, r, done, info = env.step(a)
            
            # добавляем данные в replay buffer
            done_mask = 0.0 if done else 1.0
            
            # сжимаем вознаграждения и добавляем в replay buffer
            replay_buffer.put((s, a, r / 100.0, s_prime, done_mask))

            s = s_prime

            score += r
            
            if render:
                env.render()

            if done:
                infos.append(info)
                break

        if len(replay_buffer) > replay_buffer_start_size:
            train(q, q_target, replay_buffer, optimizer, batch_size, gamma)

        if n_epi % target_update_interval == 0 and n_epi != 0:
            q_target.load_state_dict(q.state_dict())

        if n_epi % print_interval == 0 and n_epi != 0:
#             clear_output(True)
            c = collections.Counter(infos)
            print("# of episode :{}, avg score : {:.1f}, buffer size : {}, epsilon : {:.1f}%, {}".format(
                n_epi, score / print_interval, len(replay_buffer), epsilon * 100, c))
            infos = []
            score = 0.0
    env.close()
    
    return q

# %% [markdown]
# # 3. Определяем начальные параметры среды и подбираем гиперпараметры для обучения сети

# %%
from aircombat2d import Missile, Target, LineOfSight, AirCombat2D

# %%
def target_autopilot(*args):
    t, = args
    beta = 0
    return np.radians(beta)

# %%
opts = {'los': {
            'r0': 10e3, 
            'chi0': np.radians(0)
        }, 
        'missile':{
            'initial_state': {
                'vel0': 400,
                'psi0': np.radians(180)
            },
            'energetics': {
                't_act': 5,
                'omega_act': 45
            },
            'aerodynamics': {
                'Ms': np.array([0.1, 0.3, 0.5, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1., 1.05, 
                                1.1, 1.15, 1.5, 1.9, 2.3, 2.7, 3.1, 3.5, 3.9, 4.3, 4.7]),
                'Cx0_arr': np.array([0.2958, 0.2998, 0.3078, 0.3198, 0.3234, 0.3273, 0.3314, 
                                     0.3358, 0.3404, 0.3453, 0.3504, 0.3558, 0.3614, 0.4426, 
                                     0.3598, 0.2885, 0.2376, 0.2009, 0.1741, 0.1533, 0.1377, 0.1255]) * 1.5,
                'Cya_arr': np.array([0.0571, 0.0577, 0.0591, 0.0615, 0.0623, 0.0633, 0.0643, 
                                     0.0655, 0.0671, 0.0708, 0.0794, 0.0814, 0.0802, 0.0664,
                                     0.0543, 0.0465, 0.042, 0.0387, 0.0358, 0.0331, 0.0312, 0.0291]),
                'Cyb_arr': np.array([0.0571, 0.0577, 0.0591, 0.0615, 0.0623, 0.0633, 0.0643, 
                                     0.0655, 0.0671, 0.0708, 0.0794, 0.0814, 0.0802, 0.0664, 
                                     0.0543, 0.0465, 0.042, 0.0387, 0.0358, 0.0331, 0.0312, 0.0291])
            }
        }, 
        'target': {
            'vel0': 400,
            'psi0': np.radians(0)            
        }}

# %%
q = QNetwork(1024)
q_target = q
q_new = run(q,
            q_target,
            learning_rate=0.01,
            gamma=0.98,
            buffer_max_size=500000,
            batch_size=16,
            target_update_interval=10,
            replay_buffer_start_size=20000,
            print_interval=10,
            n_episodes=3000,
            n_env_steps=500)
# Out:
# # of episode :10, avg score : 31.8, buffer size : 816, epsilon : 10.0%, Counter({'out of range': 11})
# # of episode :20, avg score : 28.9, buffer size : 1559, epsilon : 9.9%, Counter({'out of range': 10})
# # of episode :30, avg score : 28.5, buffer size : 2296, epsilon : 9.8%, Counter({'out of range': 10})
# # of episode :40, avg score : 28.8, buffer size : 3036, epsilon : 9.8%, Counter({'out of range': 10})
# # of episode :50, avg score : 28.5, buffer size : 3772, epsilon : 9.8%, Counter({'out of range': 10})
# # of episode :60, avg score : 28.4, buffer size : 4507, epsilon : 9.7%, Counter({'out of range': 10})
# # of episode :70, avg score : 28.7, buffer size : 5245, epsilon : 9.7%, Counter({'out of range': 10})
# # of episode :80, avg score : 28.4, buffer size : 5981, epsilon : 9.6%, Counter({'out of range': 10})
# # of episode :90, avg score : 29.1, buffer size : 6723, epsilon : 9.6%, Counter({'out of range': 10})
# # of episode :100, avg score : 27.8, buffer size : 7452, epsilon : 9.5%, Counter({'out of range': 10})
# # of episode :110, avg score : 28.9, buffer size : 8192, epsilon : 9.4%, Counter({'out of range': 10})
# # of episode :120, avg score : 29.0, buffer size : 8934, epsilon : 9.4%, Counter({'out of range': 10})
# # of episode :130, avg score : 28.8, buffer size : 9673, epsilon : 9.3%, Counter({'out of range': 10})
# # of episode :140, avg score : 29.4, buffer size : 10419, epsilon : 9.3%, Counter({'out of range': 10})
# # of episode :150, avg score : 28.0, buffer size : 11150, epsilon : 9.2%, Counter({'out of range': 10})
# # of episode :160, avg score : 28.1, buffer size : 11881, epsilon : 9.2%, Counter({'out of range': 10})
# # of episode :170, avg score : 28.7, buffer size : 12618, epsilon : 9.2%, Counter({'out of range': 10})
# # of episode :180, avg score : 28.6, buffer size : 13356, epsilon : 9.1%, Counter({'out of range': 10})
# # of episode :190, avg score : 28.6, buffer size : 14094, epsilon : 9.1%, Counter({'out of range': 10})
# # of episode :200, avg score : 28.2, buffer size : 14826, epsilon : 9.0%, Counter({'out of range': 10})
# # of episode :210, avg score : 28.0, buffer size : 15556, epsilon : 9.0%, Counter({'out of range': 10})
# # of episode :220, avg score : 28.1, buffer size : 16288, epsilon : 8.9%, Counter({'out of range': 10})
# # of episode :230, avg score : 28.9, buffer size : 17028, epsilon : 8.9%, Counter({'out of range': 10})
# # of episode :240, avg score : 29.4, buffer size : 17772, epsilon : 8.8%, Counter({'out of range': 10})
# # of episode :250, avg score : 29.3, buffer size : 18518, epsilon : 8.8%, Counter({'out of range': 10})
# # of episode :260, avg score : 28.0, buffer size : 19247, epsilon : 8.7%, Counter({'out of range': 10})
# # of episode :270, avg score : 28.3, buffer size : 19981, epsilon : 8.7%, Counter({'out of range': 10})
# # of episode :280, avg score : 55.3, buffer size : 20952, epsilon : 8.6%, Counter({'out of range': 10})
# # of episode :290, avg score : 35.7, buffer size : 21787, epsilon : 8.6%, Counter({'out of range': 10})
# # of episode :300, avg score : 74.0, buffer size : 22981, epsilon : 8.5%, Counter({'out of range': 9, 'hit': 1})
# # of episode :310, avg score : 65.7, buffer size : 24021, epsilon : 8.5%, Counter({'out of range': 8, 'hit': 2})
# # of episode :320, avg score : 76.2, buffer size : 25186, epsilon : 8.4%, Counter({'out of range': 9, 'hit': 1})
# # of episode :330, avg score : 47.4, buffer size : 26178, epsilon : 8.3%, Counter({'out of range': 10})
# # of episode :340, avg score : 51.0, buffer size : 27179, epsilon : 8.3%, Counter({'out of range': 10})
# # of episode :350, avg score : 43.6, buffer size : 28138, epsilon : 8.2%, Counter({'out of range': 10})
# # of episode :360, avg score : 49.7, buffer size : 29183, epsilon : 8.2%, Counter({'out of range': 10})
# # of episode :370, avg score : 61.7, buffer size : 30264, epsilon : 8.2%, Counter({'out of range': 8, 'hit': 2})
# # of episode :380, avg score : 55.9, buffer size : 31334, epsilon : 8.1%, Counter({'out of range': 10})
# # of episode :390, avg score : 39.4, buffer size : 32173, epsilon : 8.1%, Counter({'out of range': 10})
# # of episode :400, avg score : 51.4, buffer size : 33133, epsilon : 8.0%, Counter({'out of range': 10})
# # of episode :410, avg score : 81.7, buffer size : 34324, epsilon : 8.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :420, avg score : 56.8, buffer size : 35285, epsilon : 7.9%, Counter({'out of range': 9, 'hit': 1})
# # of episode :430, avg score : 69.4, buffer size : 36446, epsilon : 7.9%, Counter({'out of range': 9, 'hit': 1})
# # of episode :440, avg score : 57.0, buffer size : 37467, epsilon : 7.8%, Counter({'out of range': 10})
# # of episode :450, avg score : 41.1, buffer size : 38389, epsilon : 7.8%, Counter({'out of range': 10})
# # of episode :460, avg score : 51.7, buffer size : 39397, epsilon : 7.7%, Counter({'out of range': 9, 'hit': 1})
# # of episode :470, avg score : 40.8, buffer size : 40265, epsilon : 7.7%, Counter({'out of range': 10})
# # of episode :480, avg score : 68.0, buffer size : 41395, epsilon : 7.6%, Counter({'out of range': 10})
# # of episode :490, avg score : 39.0, buffer size : 42332, epsilon : 7.6%, Counter({'out of range': 10})
# # of episode :500, avg score : 55.0, buffer size : 43401, epsilon : 7.5%, Counter({'out of range': 10})
# # of episode :510, avg score : 46.7, buffer size : 44377, epsilon : 7.5%, Counter({'out of range': 10})
# # of episode :520, avg score : 70.7, buffer size : 45455, epsilon : 7.4%, Counter({'out of range': 8, 'hit': 2})
# # of episode :530, avg score : 63.6, buffer size : 46583, epsilon : 7.4%, Counter({'out of range': 10})
# # of episode :540, avg score : 69.0, buffer size : 47635, epsilon : 7.3%, Counter({'out of range': 8, 'hit': 2})
# # of episode :550, avg score : 73.9, buffer size : 48849, epsilon : 7.3%, Counter({'out of range': 9, 'hit': 1})
# # of episode :560, avg score : 52.1, buffer size : 49787, epsilon : 7.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :570, avg score : 68.1, buffer size : 50900, epsilon : 7.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :580, avg score : 39.0, buffer size : 51720, epsilon : 7.1%, Counter({'out of range': 10})
# # of episode :590, avg score : 74.6, buffer size : 52837, epsilon : 7.1%, Counter({'out of range': 9, 'hit': 1})
# # of episode :600, avg score : 44.8, buffer size : 53830, epsilon : 7.0%, Counter({'out of range': 10})
# # of episode :610, avg score : 49.2, buffer size : 54847, epsilon : 7.0%, Counter({'out of range': 10})
# # of episode :620, avg score : 73.1, buffer size : 56089, epsilon : 6.9%, Counter({'out of range': 10})
# # of episode :630, avg score : 65.9, buffer size : 57296, epsilon : 6.9%, Counter({'out of range': 8, 'hit': 2})
# # of episode :640, avg score : 59.6, buffer size : 58366, epsilon : 6.8%, Counter({'out of range': 9, 'hit': 1})
# # of episode :650, avg score : 55.9, buffer size : 59430, epsilon : 6.8%, Counter({'out of range': 8, 'hit': 2})
# # of episode :660, avg score : 64.6, buffer size : 60480, epsilon : 6.7%, Counter({'out of range': 9, 'hit': 1})
# # of episode :670, avg score : 54.8, buffer size : 61469, epsilon : 6.7%, Counter({'out of range': 9, 'hit': 1})
# # of episode :680, avg score : 74.5, buffer size : 62647, epsilon : 6.6%, Counter({'out of range': 9, 'hit': 1})
# # of episode :690, avg score : 54.4, buffer size : 63673, epsilon : 6.6%, Counter({'out of range': 10})
# # of episode :700, avg score : 67.0, buffer size : 64773, epsilon : 6.5%, Counter({'out of range': 10})
# # of episode :710, avg score : 58.4, buffer size : 65743, epsilon : 6.5%, Counter({'out of range': 9, 'hit': 1})
# # of episode :720, avg score : 46.5, buffer size : 66717, epsilon : 6.4%, Counter({'out of range': 8, 'hit': 2})
# # of episode :730, avg score : 51.3, buffer size : 67737, epsilon : 6.3%, Counter({'out of range': 10})
# # of episode :740, avg score : 52.9, buffer size : 68771, epsilon : 6.3%, Counter({'out of range': 10})
# # of episode :750, avg score : 56.1, buffer size : 69736, epsilon : 6.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :760, avg score : 36.7, buffer size : 70580, epsilon : 6.2%, Counter({'out of range': 10})
# # of episode :770, avg score : 63.6, buffer size : 71660, epsilon : 6.2%, Counter({'out of range': 8, 'hit': 2})
# # of episode :780, avg score : 45.8, buffer size : 72603, epsilon : 6.1%, Counter({'out of range': 9, 'hit': 1})
# # of episode :790, avg score : 46.9, buffer size : 73532, epsilon : 6.1%, Counter({'out of range': 10})
# # of episode :800, avg score : 84.3, buffer size : 74760, epsilon : 6.0%, Counter({'out of range': 10})
# # of episode :810, avg score : 54.2, buffer size : 75863, epsilon : 6.0%, Counter({'out of range': 10})
# # of episode :820, avg score : 47.6, buffer size : 76824, epsilon : 5.9%, Counter({'out of range': 10})
# # of episode :830, avg score : 54.0, buffer size : 77811, epsilon : 5.9%, Counter({'out of range': 9, 'hit': 1})
# # of episode :840, avg score : 39.2, buffer size : 78649, epsilon : 5.8%, Counter({'out of range': 10})
# # of episode :850, avg score : 45.7, buffer size : 79575, epsilon : 5.8%, Counter({'out of range': 10})
# # of episode :860, avg score : 53.8, buffer size : 80529, epsilon : 5.7%, Counter({'out of range': 9, 'hit': 1})
# # of episode :870, avg score : 42.9, buffer size : 81431, epsilon : 5.7%, Counter({'out of range': 10})
# # of episode :880, avg score : 56.1, buffer size : 82406, epsilon : 5.6%, Counter({'out of range': 8, 'hit': 2})
# # of episode :890, avg score : 63.3, buffer size : 83548, epsilon : 5.5%, Counter({'out of range': 10})
# # of episode :900, avg score : 57.4, buffer size : 84519, epsilon : 5.5%, Counter({'out of range': 9, 'hit': 1})
# # of episode :910, avg score : 35.3, buffer size : 85353, epsilon : 5.5%, Counter({'out of range': 10})
# # of episode :920, avg score : 97.0, buffer size : 86640, epsilon : 5.4%, Counter({'out of range': 6, 'hit': 4})
# # of episode :930, avg score : 55.9, buffer size : 87715, epsilon : 5.3%, Counter({'out of range': 10})
# # of episode :940, avg score : 69.3, buffer size : 88855, epsilon : 5.3%, Counter({'out of range': 9, 'hit': 1})
# # of episode :950, avg score : 37.6, buffer size : 89800, epsilon : 5.3%, Counter({'out of range': 10})
# # of episode :960, avg score : 50.0, buffer size : 90720, epsilon : 5.2%, Counter({'out of range': 10})
# # of episode :970, avg score : 54.4, buffer size : 91732, epsilon : 5.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :980, avg score : 63.6, buffer size : 92791, epsilon : 5.1%, Counter({'out of range': 9, 'hit': 1})
# # of episode :990, avg score : 78.7, buffer size : 94000, epsilon : 5.1%, Counter({'out of range': 10})
# # of episode :1000, avg score : 39.0, buffer size : 94918, epsilon : 5.0%, Counter({'out of range': 10})
# # of episode :1010, avg score : 60.5, buffer size : 95933, epsilon : 5.0%, Counter({'out of range': 10})
# # of episode :1020, avg score : 71.6, buffer size : 97095, epsilon : 4.9%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1030, avg score : 47.4, buffer size : 98038, epsilon : 4.9%, Counter({'out of range': 10})
# # of episode :1040, avg score : 50.7, buffer size : 98956, epsilon : 4.8%, Counter({'out of range': 10})
# # of episode :1050, avg score : 67.6, buffer size : 100035, epsilon : 4.8%, Counter({'out of range': 7, 'hit': 3})
# # of episode :1060, avg score : 58.0, buffer size : 101059, epsilon : 4.7%, Counter({'out of range': 10})
# # of episode :1070, avg score : 44.6, buffer size : 101969, epsilon : 4.7%, Counter({'out of range': 10})
# # of episode :1080, avg score : 50.2, buffer size : 102971, epsilon : 4.6%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1090, avg score : 53.6, buffer size : 103909, epsilon : 4.6%, Counter({'out of range': 10})
# # of episode :1100, avg score : 52.1, buffer size : 104833, epsilon : 4.5%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1110, avg score : 27.8, buffer size : 105562, epsilon : 4.5%, Counter({'out of range': 10})
# # of episode :1120, avg score : 37.3, buffer size : 106388, epsilon : 4.4%, Counter({'out of range': 10})
# # of episode :1130, avg score : 38.2, buffer size : 107287, epsilon : 4.4%, Counter({'out of range': 10})
# # of episode :1140, avg score : 38.7, buffer size : 108262, epsilon : 4.3%, Counter({'out of range': 10})
# # of episode :1150, avg score : 49.0, buffer size : 109279, epsilon : 4.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1160, avg score : 27.6, buffer size : 110003, epsilon : 4.2%, Counter({'out of range': 10})
# # of episode :1170, avg score : 38.6, buffer size : 110810, epsilon : 4.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1180, avg score : 65.8, buffer size : 111894, epsilon : 4.1%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1190, avg score : 46.4, buffer size : 112839, epsilon : 4.0%, Counter({'out of range': 10})
# # of episode :1200, avg score : 49.3, buffer size : 113778, epsilon : 4.0%, Counter({'out of range': 10})
# # of episode :1210, avg score : 40.7, buffer size : 114637, epsilon : 4.0%, Counter({'out of range': 10})
# # of episode :1220, avg score : 83.8, buffer size : 115833, epsilon : 3.9%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1230, avg score : 62.4, buffer size : 116938, epsilon : 3.9%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1240, avg score : 42.6, buffer size : 117826, epsilon : 3.8%, Counter({'out of range': 10})
# # of episode :1250, avg score : 70.0, buffer size : 118930, epsilon : 3.8%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1260, avg score : 50.9, buffer size : 119869, epsilon : 3.7%, Counter({'out of range': 10})
# # of episode :1270, avg score : 50.7, buffer size : 120765, epsilon : 3.7%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1280, avg score : 50.8, buffer size : 121778, epsilon : 3.6%, Counter({'out of range': 10})
# # of episode :1290, avg score : 52.2, buffer size : 122721, epsilon : 3.6%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1300, avg score : 40.1, buffer size : 123609, epsilon : 3.5%, Counter({'out of range': 10})
# # of episode :1310, avg score : 27.4, buffer size : 124333, epsilon : 3.5%, Counter({'out of range': 10})
# # of episode :1320, avg score : 28.7, buffer size : 125134, epsilon : 3.4%, Counter({'out of range': 10})
# # of episode :1330, avg score : 101.8, buffer size : 126424, epsilon : 3.4%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1340, avg score : 64.2, buffer size : 127500, epsilon : 3.3%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1350, avg score : 67.3, buffer size : 128578, epsilon : 3.2%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1360, avg score : 43.7, buffer size : 129526, epsilon : 3.2%, Counter({'out of range': 10})
# # of episode :1370, avg score : 49.8, buffer size : 130412, epsilon : 3.2%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1380, avg score : 47.4, buffer size : 131434, epsilon : 3.1%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1390, avg score : 49.2, buffer size : 132383, epsilon : 3.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1400, avg score : 46.4, buffer size : 133334, epsilon : 3.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1410, avg score : 47.2, buffer size : 134278, epsilon : 3.0%, Counter({'out of range': 10})
# # of episode :1420, avg score : 49.3, buffer size : 135296, epsilon : 2.9%, Counter({'out of range': 10})
# # of episode :1430, avg score : 48.3, buffer size : 136501, epsilon : 2.8%, Counter({'out of range': 10})
# # of episode :1440, avg score : 51.9, buffer size : 137743, epsilon : 2.8%, Counter({'out of range': 10})
# # of episode :1450, avg score : 52.2, buffer size : 138962, epsilon : 2.8%, Counter({'out of range': 10})
# # of episode :1460, avg score : 57.9, buffer size : 140254, epsilon : 2.7%, Counter({'out of range': 10})
# # of episode :1470, avg score : 41.1, buffer size : 141220, epsilon : 2.7%, Counter({'out of range': 10})
# # of episode :1480, avg score : 45.0, buffer size : 142246, epsilon : 2.6%, Counter({'out of range': 10})
# # of episode :1490, avg score : 55.9, buffer size : 143377, epsilon : 2.6%, Counter({'out of range': 10})
# # of episode :1500, avg score : 31.1, buffer size : 144134, epsilon : 2.5%, Counter({'out of range': 10})
# # of episode :1510, avg score : 40.4, buffer size : 145060, epsilon : 2.5%, Counter({'out of range': 10})
# # of episode :1520, avg score : 35.0, buffer size : 145880, epsilon : 2.4%, Counter({'out of range': 10})
# # of episode :1530, avg score : 43.4, buffer size : 146799, epsilon : 2.4%, Counter({'out of range': 10})
# # of episode :1540, avg score : 38.7, buffer size : 147653, epsilon : 2.3%, Counter({'out of range': 10})
# # of episode :1550, avg score : 82.5, buffer size : 149064, epsilon : 2.3%, Counter({'out of range': 10})
# # of episode :1560, avg score : 34.7, buffer size : 149878, epsilon : 2.2%, Counter({'out of range': 10})
# # of episode :1570, avg score : 61.8, buffer size : 151115, epsilon : 2.2%, Counter({'out of range': 10})
# # of episode :1580, avg score : 70.6, buffer size : 152435, epsilon : 2.1%, Counter({'out of range': 10})
# # of episode :1590, avg score : 44.5, buffer size : 153348, epsilon : 2.1%, Counter({'out of range': 10})
# # of episode :1600, avg score : 66.0, buffer size : 154518, epsilon : 2.0%, Counter({'out of range': 10})
# # of episode :1610, avg score : 40.1, buffer size : 155395, epsilon : 2.0%, Counter({'out of range': 10})
# # of episode :1620, avg score : 36.1, buffer size : 156213, epsilon : 1.9%, Counter({'out of range': 10})
# # of episode :1630, avg score : 104.2, buffer size : 157686, epsilon : 1.9%, Counter({'out of range': 10})
# # of episode :1640, avg score : 32.2, buffer size : 158475, epsilon : 1.8%, Counter({'out of range': 10})
# # of episode :1650, avg score : 35.5, buffer size : 159283, epsilon : 1.8%, Counter({'out of range': 10})
# # of episode :1660, avg score : 39.0, buffer size : 160151, epsilon : 1.7%, Counter({'out of range': 10})
# # of episode :1670, avg score : 57.2, buffer size : 161116, epsilon : 1.7%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1680, avg score : 52.7, buffer size : 162069, epsilon : 1.6%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1690, avg score : 94.2, buffer size : 163352, epsilon : 1.6%, Counter({'out of range': 10})
# # of episode :1700, avg score : 105.1, buffer size : 164774, epsilon : 1.5%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1710, avg score : 66.0, buffer size : 165819, epsilon : 1.4%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1720, avg score : 118.7, buffer size : 167326, epsilon : 1.4%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1730, avg score : 66.1, buffer size : 168373, epsilon : 1.3%, Counter({'out of range': 10})
# # of episode :1740, avg score : 94.8, buffer size : 169652, epsilon : 1.3%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1750, avg score : 91.2, buffer size : 170928, epsilon : 1.2%, Counter({'out of range': 10})
# # of episode :1760, avg score : 89.6, buffer size : 172196, epsilon : 1.2%, Counter({'out of range': 10})
# # of episode :1770, avg score : 93.8, buffer size : 173532, epsilon : 1.2%, Counter({'out of range': 9, 'hit': 1})
# # of episode :1780, avg score : 88.4, buffer size : 174799, epsilon : 1.1%, Counter({'out of range': 10})
# # of episode :1790, avg score : 95.4, buffer size : 176075, epsilon : 1.1%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1800, avg score : 135.6, buffer size : 177604, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :1810, avg score : 115.9, buffer size : 178976, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :1820, avg score : 132.2, buffer size : 180434, epsilon : 1.0%, Counter({'hit': 9, 'out of range': 1})
# # of episode :1830, avg score : 131.9, buffer size : 181892, epsilon : 1.0%, Counter({'hit': 9, 'out of range': 1})
# # of episode :1840, avg score : 61.0, buffer size : 182857, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1850, avg score : 126.2, buffer size : 184308, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :1860, avg score : 85.5, buffer size : 185441, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1870, avg score : 106.1, buffer size : 186732, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :1880, avg score : 103.7, buffer size : 188019, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1890, avg score : 85.0, buffer size : 189148, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1900, avg score : 117.7, buffer size : 190523, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :1910, avg score : 71.6, buffer size : 191569, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1920, avg score : 97.0, buffer size : 192781, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :1930, avg score : 97.9, buffer size : 194061, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :1940, avg score : 94.8, buffer size : 195271, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1950, avg score : 112.6, buffer size : 196641, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :1960, avg score : 93.1, buffer size : 197848, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :1970, avg score : 116.0, buffer size : 199219, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :1980, avg score : 119.4, buffer size : 200593, epsilon : 1.0%, Counter({'hit': 7, 'out of range': 3})
# # of episode :1990, avg score : 90.9, buffer size : 201798, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2000, avg score : 83.5, buffer size : 202926, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2010, avg score : 115.6, buffer size : 204297, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2020, avg score : 85.0, buffer size : 205429, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2030, avg score : 117.2, buffer size : 206801, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2040, avg score : 105.8, buffer size : 208090, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2050, avg score : 94.2, buffer size : 209301, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2060, avg score : 83.9, buffer size : 210429, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2070, avg score : 84.1, buffer size : 211558, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2080, avg score : 105.3, buffer size : 212849, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2090, avg score : 103.1, buffer size : 214137, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2100, avg score : 96.6, buffer size : 215349, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2110, avg score : 92.9, buffer size : 216558, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2120, avg score : 79.8, buffer size : 217682, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2130, avg score : 79.8, buffer size : 218803, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2140, avg score : 62.2, buffer size : 219769, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2150, avg score : 106.2, buffer size : 221062, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2160, avg score : 85.3, buffer size : 222193, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2170, avg score : 97.0, buffer size : 223405, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2180, avg score : 84.6, buffer size : 224536, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2190, avg score : 94.4, buffer size : 225747, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2200, avg score : 108.2, buffer size : 227042, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2210, avg score : 84.8, buffer size : 228175, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2220, avg score : 92.1, buffer size : 229383, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2230, avg score : 82.5, buffer size : 230511, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2240, avg score : 93.7, buffer size : 231720, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2250, avg score : 74.6, buffer size : 232769, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2260, avg score : 83.8, buffer size : 233900, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2270, avg score : 72.7, buffer size : 234948, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2280, avg score : 69.1, buffer size : 235992, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2290, avg score : 86.3, buffer size : 237122, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2300, avg score : 85.6, buffer size : 238253, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2310, avg score : 95.0, buffer size : 239463, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2320, avg score : 85.6, buffer size : 240595, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2330, avg score : 104.7, buffer size : 241886, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2340, avg score : 59.7, buffer size : 242850, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2350, avg score : 70.2, buffer size : 243896, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2360, avg score : 83.4, buffer size : 245026, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2370, avg score : 84.6, buffer size : 246155, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2380, avg score : 59.7, buffer size : 247121, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2390, avg score : 102.1, buffer size : 248407, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2400, avg score : 113.9, buffer size : 249775, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2410, avg score : 83.1, buffer size : 250902, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2420, avg score : 79.3, buffer size : 252025, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2430, avg score : 71.8, buffer size : 253073, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2440, avg score : 93.3, buffer size : 254283, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2450, avg score : 93.6, buffer size : 255491, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2460, avg score : 93.4, buffer size : 256700, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2470, avg score : 114.2, buffer size : 258069, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2480, avg score : 86.4, buffer size : 259201, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2490, avg score : 93.1, buffer size : 260409, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2500, avg score : 57.9, buffer size : 261370, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2510, avg score : 71.1, buffer size : 262416, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2520, avg score : 86.3, buffer size : 263546, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2530, avg score : 69.2, buffer size : 264588, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2540, avg score : 83.9, buffer size : 265715, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2550, avg score : 71.2, buffer size : 266761, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2560, avg score : 117.3, buffer size : 268133, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2570, avg score : 98.1, buffer size : 269345, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2580, avg score : 83.5, buffer size : 270477, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2590, avg score : 82.3, buffer size : 271606, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2600, avg score : 84.7, buffer size : 272737, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2610, avg score : 86.3, buffer size : 273867, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2620, avg score : 69.2, buffer size : 274911, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2630, avg score : 106.0, buffer size : 276203, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2640, avg score : 73.8, buffer size : 277252, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2650, avg score : 84.9, buffer size : 278381, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2660, avg score : 70.2, buffer size : 279425, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2670, avg score : 70.3, buffer size : 280470, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2680, avg score : 60.4, buffer size : 281436, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2690, avg score : 70.2, buffer size : 282480, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2700, avg score : 58.6, buffer size : 283446, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2710, avg score : 80.3, buffer size : 284571, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2720, avg score : 117.7, buffer size : 285943, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2730, avg score : 85.0, buffer size : 287072, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2740, avg score : 69.3, buffer size : 288115, epsilon : 1.0%, Counter({'out of range': 8, 'hit': 2})
# # of episode :2750, avg score : 86.5, buffer size : 289246, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2760, avg score : 83.2, buffer size : 290373, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2770, avg score : 81.8, buffer size : 291499, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2780, avg score : 74.0, buffer size : 292547, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2790, avg score : 93.6, buffer size : 293757, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2800, avg score : 95.0, buffer size : 294966, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2810, avg score : 95.9, buffer size : 296177, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2820, avg score : 84.0, buffer size : 297305, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2830, avg score : 94.9, buffer size : 298515, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2840, avg score : 94.6, buffer size : 299725, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2850, avg score : 94.5, buffer size : 300935, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2860, avg score : 96.0, buffer size : 302145, epsilon : 1.0%, Counter({'out of range': 5, 'hit': 5})
# # of episode :2870, avg score : 98.2, buffer size : 303357, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2880, avg score : 69.6, buffer size : 304402, epsilon : 1.0%, Counter({'out of range': 9, 'hit': 1})
# # of episode :2890, avg score : 73.2, buffer size : 305450, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2900, avg score : 83.1, buffer size : 306577, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2910, avg score : 107.4, buffer size : 307870, epsilon : 1.0%, Counter({'hit': 6, 'out of range': 4})
# # of episode :2920, avg score : 74.1, buffer size : 308920, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2930, avg score : 72.2, buffer size : 309968, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2940, avg score : 82.4, buffer size : 311098, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2950, avg score : 92.2, buffer size : 312306, epsilon : 1.0%, Counter({'out of range': 6, 'hit': 4})
# # of episode :2960, avg score : 86.3, buffer size : 313436, epsilon : 1.0%, Counter({'hit': 5, 'out of range': 5})
# # of episode :2970, avg score : 92.3, buffer size : 314643, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2980, avg score : 69.2, buffer size : 315684, epsilon : 1.0%, Counter({'out of range': 7, 'hit': 3})
# # of episode :2990, avg score : 109.4, buffer size : 316979, epsilon : 1.0%, Counter({'hit': 7, 'out of range': 3})

# %%
q_new.state_dict()

# %%
run(q,
    q_target,
    learning_rate=0.05,
    gamma=0.99,
    buffer_max_size=500000,
    batch_size=16,
    target_update_interval=10,
    replay_buffer_start_size=50000,
    print_interval=10,
    n_episodes=1,
    n_env_steps=500,
    render=True, 
    epsilon0 = 0.01)
# Out:
# QNetwork(
#   (fc1): Linear(in_features=8, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=3, bias=True)
# )

# %%
env = AirCombat2D(opts)
print("Action space:",env.action_space)
print("Observation space:", env.observation_space.low)

# %%
env = gym.wrappers.TimeLimit(AirCombat2D(opts,altitude=15e3,target_autopilot=target_autopilot).unwrapped, max_episode_steps=500)
# проводим инициализацию и запоминаем начальное состояние
s = env.reset()

done = False

while not done:
    
    a = q_new.sample_action(torch.from_numpy(s).float(), 0.01)
    
    # выполняем действие, получаем s, r, done
    s, r, done, info = env.step(a)
    
    # визуализируем окружение
    env.render()

#     print(f"Время выполнения {it} шага: {round(time() - timeit, 3)} с", end="\r")

clear_output(True)

env.close()
if s[0] < 10:
    print("Успех!")
else:
    print(f"Не успех: {info}")
